# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# Import API key
import api_keys

# %% [markdown]
# ## Build Team List

# %%
# Get API Key from local file
api_key = api_keys.api_key

# Construct url for API call
access_level = 'trial'
version = 'v4'
language_code = 'en'
data_format = 'json'
leagueHeirarchyUrl = f"https://api.sportradar.us/ncaamb/{access_level}/{version}/" + \
    "{language_code}/league/hierarchy.{data_format}?api_key={api_key}"


# Request data for constructing team list from API endpoint
raw_data = requests.get(leagueHeirarchyUrl).json()
print(f"Pulled JSON from \n{leagueHeirarchyUrl}")
# Out:
# Pulled JSON from
# https://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?api_key=dzsdr8tp6f3sxcmwuzacchwn

# %%
# Build list of team ids to use when calling API

team_ids = []
for division in raw_data['divisions']:
    if (division['name']=='NCAA Division I'):
        for conference in division['conferences']:
            for team in conference['teams']:
                team_ids.append({
                    "id":          team['id'],
                    "school_name": team['market'],
                    "team_name":   team['name'],
                    "conference":  conference['name']
                })

pprint(team_ids[:2])
# Out:
# [{'conference': 'Pacific 12',
#   'id': '0d037a5d-827a-44dd-8b70-57603d671d5d',
#   'school_name': 'Utah',
#   'team_name': 'Utes'},
#  {'conference': 'Pacific 12',
#   'id': '1da70895-f77f-44ef-b216-d63c02e696eb',
#   'school_name': 'Oregon',
#   'team_name': 'Ducks'}]

# %% [markdown]
# ## Limit query to subset of schools, if desired

# %%
# # --- Query for two specific schools ----
# test_schools = ['Kentucky', 'Purdue']
# trimmed_team_ids = []
# for team in team_ids: 
#     if team['school_name'] in test_schools:
#         trimmed_team_ids.append(team)
#         print(f"Added {team['school_name']} to test_schools.")


# # --- Query for major conference schools ----
# major_conferences = ['Pacific 12', 'Atlantic Coast', 'Big Ten', 'Big East', 'Big 12']
# trimmed_team_ids = []
# for team in team_ids: 
#     if team['conference'] in major_conferences:
#         trimmed_team_ids.append(team)
#         print(f"Added {team['school_name']} to trimmed_team_ids.")

# %% [markdown]
# ## Set output file name and query selected schools from API

# %%
# Set name of output data file
output_data_file = "raw-allteams-regseason.txt"

# %%
# Get API Key from local file
api_key = api_keys.api_key

# Construct url for API call
access_level = 'trial'
version = 'v4'
language_code = 'en'
season_year = '2018'
ncaamb_season = 'REG'
team_id = ''
data_format = 'json'

# Iterate through team_ids and pull seasonal data for each
output_data = []
for team in team_ids:
    
    # Build URL for team-specific API call
    team_id = team['id']
    url = f"https://api.sportradar.us/ncaamb/{access_level}/{version}/{language_code}/seasons/" + \
    f"{season_year}/{ncaamb_season}/teams/{team_id}/statistics.{data_format}?api_key={api_key}"

    # Make request to API
    response = requests.get(url)
    if (response.status_code == 200):
        print(f"Response received for {team['school_name']} {team['team_name']}")
        output_data.append(response.json())
        time.sleep(1)
    else:
        print(f"Request FAILED for {team['school_name']} {team['team_name']}")

with open(output_data_file, 'w') as outfile:  
    json.dump(output_data, outfile)
    print('************************************************')
    print(f"Saved returned data to {output_data_file}")
# Out:
# Response received for Utah Utes
# Response received for Oregon Ducks
# Response received for Washington State Cougars
# Response received for USC Trojans
# Response received for Oregon State Beavers
# Response received for Stanford Cardinal
# Response received for Arizona Wildcats
# Response received for Colorado Buffaloes
# Response received for California Golden Bears
# Response received for Arizona State Sun Devils
# Response received for Washington Huskies
# Response received for UCLA Bruins
# Response received for Jacksonville State Gamecocks
# Response received for Eastern Illinois Panthers
# Response received for Southeast Missouri State Redhawks
# Response received for Murray State Racers
# Response received for Tennessee State Tigers
# Response received for Tennessee-Martin Skyhawks
# Response received for Belmont Bruins
# Response received for Austin Peay Governors
# Response received for Morehead State Eagles
# Response received for SIU-Edwardsville Cougars
# Response received for Eastern Kentucky Colonels
# Response received for Tennessee Tech Golden Eagles
# Response received for Indiana State Sycamores
# Response received for Northern Iowa Panthers
# Response received for Illinois State Redbirds
# Response received for Loyola (IL) Ramblers
# Response received for Southern Illinois Salukis
# Response received for Drake Bulldogs
# Response received for Bradley Braves
# Response received for Missouri State Bears
# Response received for Evansville Purple Aces
# Response received for Valparaiso Crusaders
# Response received for Iowa State Cyclones
# Response received for Texas Longhorns
# Response received for Oklahoma State Cowboys
# Response received for Oklahoma Sooners
# Response received for Kansas State Wildcats
# Response received for Baylor Bears
# Response received for West Virginia Mountaineers
# Response received for TCU Horned Frogs
# Response received for Texas Tech Red Raiders
# Response received for Kansas Jayhawks
# Response received for Arkansas-Little Rock Trojans
# Response received for South Alabama Jaguars
# Response received for Louisiana-Monroe Warhawks
# Response received for Texas State Bobcats
# Response received for Coastal Carolina Chanticleers
# Response received for Troy Trojans
# Response received for Louisiana-Lafayette Ragin' Cajuns
# Response received for Georgia Southern Eagles
# Response received for Texas-Arlington Mavericks
# Response received for Appalachian State Mountaineers
# Response received for Georgia State Panthers
# Response received for Arkansas State Red Wolves
# Response received for Northern Arizona Lumberjacks
# Response received for Sacramento State Hornets
# Response received for Weber State Wildcats
# Response received for Eastern Washington Eagles
# Response received for Idaho State Bengals
# Response received for Portland State Vikings
# Response received for Northern Colorado Bears
# Response received for Montana State Bobcats
# Response received for Southern Utah Thunderbirds
# Response received for Montana Grizzlies
# Response received for Idaho Vandals
# Response received for UCF Knights
# Response received for Memphis Tigers
# Response received for Houston Cougars
# Response received for Tulsa Golden Hurricane
# Response received for Tulane Green Wave
# Response received for SMU Mustangs
# Response received for South Florida Bulls
# Response received for Temple Owls
# Response received for Cincinnati Bearcats
# Response received for East Carolina Pirates
# Response received for Connecticut Huskies
# Response received for Wichita State Shockers
# Response received for Virginia Military Keydets
# Response received for Citadel Bulldogs
# Response received for Chattanooga Mocs
# Response received for UNC Greensboro Spartans
# Response received for Western Carolina Catamounts
# Response received for Wofford Terriers
# Response received for Mercer Bears
# Response received for Samford Bulldogs
# Response received for Furman Paladins
# Response received for East Tennessee State Buccaneers
# Response received for Oral Roberts Golden Eagles
# Response received for Purdue Fort Wayne Mastodons
# Response received for Nebraska-Omaha Mavericks
# Response received for South Dakota State Jackrabbits
# Response received for Denver Pioneers
# Response received for North Dakota State Bison
# Response received for South Dakota Coyotes
# Response received for Western Illinois Leathernecks
# Response received for North Dakota Fighting Hawks
# Response received for Long Beach State 49ers
# Response received for UC Irvine Anteaters
# Response received for UC Santa Barbara Gauchos
# Response received for Cal Poly Mustangs
# Response received for UC Riverside Highlanders
# Response received for UC Davis Aggies
# Response received for Cal State Fullerton Titans
# Response received for Cal State Northridge Matadors
# Response received for Hawaii Warriors
# Response received for UTEP Miners
# Response received for North Texas Mean Green
# Response received for Middle Tennessee Blue Raiders
# Response received for Marshall Thundering Herd
# Response received for Southern Miss Golden Eagles
# Response received for UAB Blazers
# Response received for Western Kentucky Hilltoppers
# Response received for Charlotte 49ers
# Response received for Louisiana Tech Bulldogs
# Response received for UTSA Roadrunners
# Response received for Florida International Golden Panthers
# Response received for Rice Owls
# Response received for Florida Atlantic Owls
# Response received for Old Dominion Monarchs
# Response received for Cal State Bakersfield Roadrunners
# Response received for Chicago State Cougars
# Response received for Utah Valley Wolverines
# Response received for New Mexico State Aggies
# Response received for Seattle Redhawks
# Response received for UMKC Kangaroos
# Response received for Texas Rio Grande Valley Vaqueros
# Response received for California Baptist Lancers
# Response received for Grand Canyon Antelopes
# Response received for Southeastern Louisiana Lions
# Response received for Stephen F. Austin Lumberjacks
# Response received for Sam Houston State Bearkats
# Response received for Northwestern State Demons
# Response received for Incarnate Word Cardinals
# Response received for Houston Baptist Huskies
# Response received for Abilene Christian Wildcats
# Response received for Nicholls State Colonels
# Response received for McNeese State Cowboys
# Response received for Central Arkansas Bears
# Response received for New Orleans Privateers
# Response received for Lamar Cardinals
# Response received for Texas A&M-CC Islanders
# Response received for Arkansas-Pine Bluff Golden Lions
# Response received for Alcorn State Braves
# Response received for Alabama State Hornets
# Response received for Mississippi Valley State Delta Devils
# Response received for Grambling State Tigers
# Response received for Prairie View A&M Panthers
# Response received for Alabama A&M Bulldogs
# Response received for Southern University Jaguars
# Response received for Jackson State Tigers
# Response received for Texas Southern Tigers
# Response received for Bethune-Cookman Wildcats
# Response received for Howard Bison
# Response received for Savannah State Tigers
# Response received for North Carolina A&T Aggies
# Response received for Morgan State Bears
# Response received for Coppin State Eagles
# Response received for South Carolina State Bulldogs
# Response received for Norfolk State Spartans
# Response received for Florida A&M Rattlers
# Response received for Maryland-Eastern Shore Hawks
# Response received for North Carolina Central Eagles
# Response received for Delaware State Hornets
# Response received for Georgia Tech Yellow Jackets
# Response received for Pittsburgh Panthers
# Response received for Virginia Tech Hokies
# Response received for Boston College Eagles
# Response received for Wake Forest Demon Deacons
# Response received for North Carolina State Wolfpack
# Response received for Virginia Cavaliers
# Response received for Miami (FL) Hurricanes
# Response received for Notre Dame Fighting Irish
# Response received for Syracuse Orange
# Response received for Louisville Cardinals
# Response received for Florida State Seminoles
# Response received for Clemson Tigers
# Response received for North Carolina Tar Heels
# Response received for Duke Blue Devils
# Response received for North Florida Ospreys
# Response received for Kennesaw State Owls
# Response received for Stetson Hatters
# Response received for N.J.I.T. Highlanders
# Response received for Florida Gulf Coast Eagles
# Response received for Liberty Flames
# Response received for North Alabama Lions
# Response received for Lipscomb Bisons
# Response received for Jacksonville Dolphins
# Response received for Loyola (MD) Greyhounds
# Response received for American University Eagles
# Response received for Holy Cross Crusaders
# Response received for Navy Midshipmen
# Response received for Lehigh Mountain Hawks
# Response received for Lafayette Leopards
# Response received for Army Black Knights
# Response received for Colgate Raiders
# Response received for Bucknell Bison
# Response received for Boston University Terriers
# Response received for Hampton Pirates
# Response received for USC Upstate Spartans
# Response received for Longwood Lancers
# Response received for Campbell Fighting Camels
# Response received for Gardner-Webb Runnin' Bulldogs
# Response received for High Point Panthers
# Response received for Charleston Southern Buccaneers
# Response received for UNC Asheville Bulldogs
# Response received for Presbyterian Blue Hose
# Response received for Winthrop Eagles
# Response received for Radford Highlanders
# Response received for Detroit Mercy Titans
# Response received for Milwaukee Panthers
# Response received for Green Bay Phoenix
# Response received for IUPUI Jaguars
# Response received for Wright State Raiders
# Response received for Northern Kentucky Norse
# Response received for Oakland Golden Grizzlies
# Response received for Youngstown State Penguins
# Response received for Illinois-Chicago Flames
# Response received for Cleveland State Vikings
# Response received for Colorado State Rams
# Response received for New Mexico Lobos
# Response received for San Jose State Spartans
# Response received for Nevada Wolf Pack
# Response received for UNLV Rebels
# Response received for Utah State Aggies
# Response received for Wyoming Cowboys
# Response received for Air Force Falcons
# Response received for Boise State Broncos
# Response received for Fresno State Bulldogs
# Response received for San Diego State Aztecs
# Response received for Auburn Tigers
# Response received for South Carolina Gamecocks
# Response received for Kentucky Wildcats
# Response received for Georgia Bulldogs
# Response received for LSU Tigers
# Response received for Vanderbilt Commodores
# Response received for Missouri Tigers
# Response received for Florida Gators
# Response received for Mississippi State Bulldogs
# Response received for Tennessee Volunteers
# Response received for Alabama Crimson Tide
# Response received for Arkansas Razorbacks
# Response received for Ole Miss Rebels
# Response received for Texas A&M Aggies
# Response received for Miami (OH) RedHawks
# Response received for Eastern Michigan Eagles
# Response received for Ball State Cardinals
# Response received for Ohio Bobcats
# Response received for Toledo Rockets
# Response received for Kent State Golden Flashes
# Response received for Northern Illinois Huskies
# Response received for Central Michigan Chippewas
# Response received for Akron Zips
# Response received for Bowling Green Falcons
# Response received for Buffalo Bulls
# Response received for Western Michigan Broncos
# Response received for Purdue Boilermakers
# Response received for Illinois Fighting Illini
# Response received for Maryland Terrapins
# Response received for Penn State Nittany Lions
# Response received for Northwestern Wildcats
# Response received for Ohio State Buckeyes
# Response received for Michigan State Spartans
# Response received for Rutgers Scarlet Knights
# Response received for Michigan Wolverines
# Response received for Iowa Hawkeyes
# Response received for Indiana Hoosiers
# Response received for Wisconsin Badgers
# Response received for Nebraska Cornhuskers
# Response received for Minnesota Golden Gophers
# Response received for Maine Black Bears
# Response received for Vermont Catamounts
# Response received for Stony Brook Seawolves
# Response received for Albany Great Danes
# Response received for UMBC Retrievers
# Response received for Massachusetts-Lowell River Hawks
# Response received for New Hampshire Wildcats
# Response received for Hartford Hawks
# Response received for Binghamton Bearcats
# Response received for Sacred Heart Pioneers
# Response received for Wagner Seahawks
# Response received for Mount St. Mary's Mountaineers
# Response received for Bryant University Bulldogs
# Response received for St. Francis (PA) Red Flash
# Response received for Robert Morris Colonials
# Response received for LIU Brooklyn Blackbirds
# Response received for Central Connecticut State Blue Devils
# Response received for Fairleigh Dickinson Knights
# Response received for St. Francis (BKN) Terriers
# Response received for Brown Bears
# Response received for Harvard Crimson
# Response received for Cornell Big Red
# Response received for Yale Bulldogs
# Response received for Columbia Lions
# Response received for Dartmouth Big Green
# Response received for Pennsylvania Quakers
# Response received for Princeton Tigers
# Response received for Delaware Fightin Blue Hens
# Response received for Hofstra Pride
# Response received for James Madison Dukes
# Response received for Towson Tigers
# Response received for Charleston Cougars
# Response received for Elon Phoenix
# Response received for Northeastern Huskies
# Response received for William & Mary Tribe
# Response received for North Carolina-Wilmington Seahawks
# Response received for Drexel Dragons
# Response received for Pepperdine Waves
# Response received for Portland Pilots
# Response received for Santa Clara Broncos
# Response received for Gonzaga Bulldogs
# Response received for Loyola Marymount Lions
# Response received for San Diego Toreros
# Response received for Saint Mary's Gaels
# Response received for BYU Cougars
# Response received for Pacific Tigers
# Response received for San Francisco Dons
# Response received for Marquette Golden Eagles
# Response received for Xavier Musketeers
# Response received for Villanova Wildcats
# Response received for Providence Friars
# Response received for Creighton Bluejays
# Response received for Georgetown Hoyas
# Response received for Seton Hall Pirates
# Response received for Butler Bulldogs
# Response received for St. John's Red Storm
# Response received for DePaul Blue Demons
# Response received for Saint Louis Billikens
# Response received for St. Bonaventure Bonnies
# Response received for Davidson Wildcats
# Response received for Dayton Flyers
# Response received for Fordham Rams
# Response received for Rhode Island Rams
# Response received for Massachusetts Minutemen
# Response received for Richmond Spiders
# Response received for La Salle Explorers
# Response received for Virginia Commonwealth Rams
# Response received for George Washington Colonials
# Response received for George Mason Patriots
# Response received for Saint Joseph's (PA) Hawks
# Response received for Duquesne Dukes
# Response received for Canisius Golden Griffins
# Response received for Rider Broncs
# Response received for Marist Red Foxes
# Response received for Iona Gaels
# Response received for Monmouth Hawks
# Response received for Quinnipiac Bobcats
# Response received for Manhattan Jaspers
# Response received for Fairfield Stags
# Response received for Siena Saints
# Response received for St. Peter's Peacocks
# Response received for Niagara Purple Eagles
# ************************************************
# Saved returned data to raw-powerconf_regseason.txt
